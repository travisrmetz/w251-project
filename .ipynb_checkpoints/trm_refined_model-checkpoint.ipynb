# %% [markdown]
# ## General Model

# %% [markdown]
# ## Import useful packages

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
import boto3
import io
from keras.utils import plot_model
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define functions to load the data

# %% [markdown]
# #### This code gets list of keys (ie files) in S3 bucket
# (Should consider moving this into a helper file.)

# %%
def get_matching_s3_objects(bucket, prefix="", suffix=""):
    """
    Generate objects in an S3 bucket.

    :param bucket: Name of the S3 bucket.
    :param prefix: Only fetch objects whose key starts with
        this prefix (optional).
    :param suffix: Only fetch objects whose keys end with
        this suffix (optional).
    """
    s3 = boto3.client("s3")
    paginator = s3.get_paginator("list_objects_v2")

    kwargs = {'Bucket': bucket}

    # We can pass the prefix directly to the S3 API.  If the user has passed
    # a tuple or list of prefixes, we go through them one by one.
    if isinstance(prefix, str):
        prefixes = (prefix, )
    else:
        prefixes = prefix

    for key_prefix in prefixes:
        kwargs["Prefix"] = key_prefix

        for page in paginator.paginate(**kwargs):
            try:
                contents = page["Contents"]
            except KeyError:
                break

            for obj in contents:
                key = obj["Key"]
                if key.endswith(suffix):
                    yield obj


def get_matching_s3_keys(bucket, prefix="", suffix=""):
    """
    Generate the keys in an S3 bucket.

    :param bucket: Name of the S3 bucket.
    :param prefix: Only fetch keys that start with this prefix (optional).
    :param suffix: Only fetch keys that end with this suffix (optional).
    """
    obj_list=[]
    for obj in get_matching_s3_objects(bucket, prefix, suffix):
        obj_list.append(obj["Key"])
    return(obj_list)

# %% [markdown]
# ### Key image read-in functions: load_image and build_input

# %%
def load_image(s3_client,bucket_name,file_name, dim=(224,224)):
    """
    Loads a single image as a Numpy array and resizes it as
    desired.  The default dimensions are consistent with
    those expected by the VGG models.  

    Args:
    s3_client:  s3 resource
    bucket_name:name of bucket
    file_name:  file to convert to image

    dim: Two-element tuple giving the desired height
         and width of the processed image

    Returns:
    image:  A single-channel Numpy array
    """
    #image = cv2.imread(image_path, 0)
    file_stream = io.BytesIO()
    s3.download_fileobj(bucket_name,file_name,file_stream)
    nparr = np.frombuffer(file_stream.getvalue(), np.uint8)
    image=cv2.imdecode(nparr,0)
    image = cv2.resize(image, dim)#, interpolation = cv2.INTER_AREA)
    return image

# %%
def build_input(s3_client,bucket_name,file_list,files_to_load):
    """
    Loads all of the images into a single numpy array.
    Assumes that there are 101 equally-spaced images
    spanning lattitudes from 35N to 45N.  

    Args:
    s3_client:  s3 resource
    bucket_name:name of bucket
    file_list:  list of files in bucket
    Returns:
    X:  A 3-dimensional numpy array containing the
        images. Image height and width are set by
        `load_images` and default to 224 x 224.

    y:  A 1-dimensional numpy array of target lattitudes.
    """
    X = []
    i=0
    for file in file_list[0:files_to_load]:
        if file[-4:] == '.png':
            print(file)
            image = load_image(s3_client,bucket_name,file)
            X.append(image)
            if i%100==0:
                print('loaded:',i)
            i+=1
    return (np.array(X) / 255)

# %%
def build_labels(file_list,files_to_load):
    y = []
    for file in file_list[0:files_to_load]:
        if file[-4:] == '.png':
            file_split = file.split('+')
            lat = float(file_split[0])
            long = float(file_split[1])
            y.append((lat, long))
    return np.array(y)

# %% [markdown]
# #### Test load_image on one image manually

# %%
bucket_name='w251-final-project'
file_name='30.012009870092356+-56.94677555465446+2020-07-04T01:00:00.png'
s3 = boto3.client('s3')
sample_image = load_image(s3,bucket_name,file_name)
plt.imshow(sample_image)
print(sample_image.shape)
# Out:
# (224, 224)

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# ### Load the images

# %%
#clear out models for memory management purposes
tf.keras.backend.clear_session()

#change this to true to force it to reload from S3 bucket
force_load=True

#check if np arrays have already been saved and load if so
if ((os.path.exists('x.npy'))&(not force_load)):
    print('loading from files')
    X=np.load('x.npy')
    y=np.load('y.npy')

#otherwise go to S3 bucket
else:
    print('loading from S3')
    bucket_name='w251-final-project'
    file_list=get_matching_s3_keys(bucket_name)
    
    #shuffle file list so that if take less than all are distributed.  also makes array randomly shuffled
    random.shuffle(file_list)
    
    s3 = boto3.client('s3')

    #max_files=100000
    max_files=5000
    file_list_length=len(file_list)
    files_to_load=np.minimum(max_files,file_list_length)

    #get images
    print('about to call build_input on',files_to_load,' files')
    X = build_input(s3,bucket_name,file_list,files_to_load)


    #get labels
    print ('building labels')
    y = build_labels(file_list,files_to_load)
    
    print ('saving arrays so can reload more easily next time through')
    np.save('x.npy',X)
    np.save('y.npy',y)

print ('shape of image array:', X.shape)
print ('shape of label list:', y.shape)
# Out:
# loading from S3
# about to call build_input on 5000  files
# 37.189074095642+-50.01414631916696+2020-07-04T01:00:00.png
# loaded: 0
# 40.970252363626315+-65.12310191721757+2020-07-04T01:00:00.png
# 36.51302796741632+-64.6969003659294+2020-07-04T01:00:00.png
# 39.325314930545936+-57.35820778362642+2020-07-04T01:00:00.png
# 35.105105845344696+-53.98086721198472+2020-07-04T01:00:00.png
# 42.75501012184912+-68.54650630788286+2020-07-04T01:00:00.png
# 43.07437566656975+-64.33560460549695+2020-07-04T01:00:00.png
# 43.924654812744805+-59.23993209486361+2020-07-04T01:00:00.png
# 44.52923830162394+-69.51522941956091+2020-07-04T01:00:00.png
# 42.44106351423956+-58.578501845901286+2020-07-04T01:00:00.png
# 36.8160245360349+-52.482917197879374+2020-07-04T01:00:00.png
# 42.27462492768657+-61.70708092600276+2020-07-04T01:00:00.png
# 41.11156575624912+-61.21967352327407+2020-07-04T01:00:00.png
# 36.004878531020225+-55.46282116712657+2020-07-04T01:00:00.png
# 31.736078785967983+-60.309416708582134+2020-07-04T01:00:00.png
# 39.25798303502084+-56.678388721812524+2020-07-04T01:00:00.png
# 36.83421352665022+-56.455888020274095+2020-07-04T01:00:00.png
# 31.49995824673395+-58.98728176522713+2020-07-04T01:00:00.png
# 32.283771197679776+-54.562903814677284+2020-07-04T01:00:00.png
# 40.91103414168198+-66.47436981561995+2020-07-04T01:00:00.png
# 30.719222426897847+-62.9299287159025+2020-07-04T01:00:00.png
# 36.97543379347935+-55.57654532525925+2020-07-04T01:00:00.png
# 31.498822290658712+-60.03230894734746+2020-07-04T01:00:00.png
# 38.4992340959512+-50.10823501619052+2020-07-04T01:00:00.png
# 45.3937894557451+-52.46570450456887+2020-07-04T01:00:00.png
# 34.11046329018161+-51.50653840678416+2020-07-04T01:00:00.png
# 38.89941024446922+-59.51008053946943+2020-07-04T01:00:00.png
# 43.24557806478272+-65.73165775267846+2020-07-04T01:00:00.png
# 41.91935306426648+-68.60983630518258+2020-07-04T01:00:00.png
# 36.78261296696382+-56.96114423214205+2020-07-04T01:00:00.png
# 44.04986986174963+-65.42403243490696+2020-07-04T01:00:00.png
# 43.15948091708724+-52.94723723413536+2020-07-04T01:00:00.png
# 32.51394111312555+-66.00020019127611+2020-07-04T01:00:00.png
# 42.52439685935458+-58.07120063024894+2020-07-04T01:00:00.png
# 42.638460234332086+-51.536989807220586+2020-07-04T01:00:00.png
# 39.82319719178368+-51.727292076403785+2020-07-04T01:00:00.png
# 46.58490895745193+-54.86678076922068+2020-07-04T01:00:00.png
# 44.43288463150988+-53.299996302334364+2020-07-04T01:00:00.png
# 40.55164604465178+-55.83834731093364+2020-07-04T01:00:00.png
# 32.081493226717825+-60.25899984687344+2020-07-04T01:00:00.png
# 47.47024614850253+-58.73298084678464+2020-07-04T01:00:00.png
# 48.36626590335336+-68.16462594595468+2020-07-04T01:00:00.png
# 47.49004025583844+-64.97930316113982+2020-07-04T01:00:00.png
# 41.72306382340909+-66.74556784244409+2020-07-04T01:00:00.png
# 48.4208798760214+-66.3670110310776+2020-07-04T01:00:00.png
# 40.60360800282059+-62.27761744995421+2020-07-04T01:00:00.png
# 49.802828649640254+-66.86711343913619+2020-07-04T01:00:00.png
# 36.25696838598586+-58.581918654162436+2020-07-04T01:00:00.png
# 37.14476290367085+-65.85891168650306+2020-07-04T01:00:00.png
# 32.03524132432593+-51.81478167696534+2020-07-04T01:00:00.png
# 32.34343880188181+-59.07946530959765+2020-07-04T01:00:00.png
# 44.60075999036224+-59.98304221425121+2020-07-04T01:00:00.png
# building labels
# saving arrays so can reload more easily next time through
# shape of image array: (5000, 224, 224)
# shape of label list: (5000, 2)

# %% [markdown]
# ### Standardize the values

# %%
def scale_down(numbers):
    top=max(numbers)
    bottom=min(numbers)
    middle=(top+bottom)/2
    number_range=top-bottom
    revised=[x-middle for x in numbers]
    revised=[x/number_range*2 for x in revised]
    return revised,top,bottom

def scale_up(numbers,top,bottom):
    middle=(top+bottom)/2
    number_range=top-bottom
    revised=[x*number_range/2 for x in numbers]
    revised=[x+middle for x in revised]
    return revised

# %%
#just scaling down without normalizing
y[:,0],toplat,bottomlat=scale_down(y[:,0])
y[:,1],toplong,bottomlong=scale_down(y[:,1])

#y[:,0] = scale(y[:,0])
#y[:,1]=scale(y[:,1])

print (y[:,0].mean(),y[:,0].std())
print (y[:,1].mean(),y[:,1].std())
# Out:
# 0.004165487753433775 0.5719736943319929
# 0.00983923382587118 0.5821570450279536

# %% [markdown]
# ### Split into test and training sets

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (4000, 224, 224)
# (4000, 2)
# (1000, 224, 224)
# (1000, 2)

# %% [markdown]
# ### Add channel for CNN

# %%
#need to add channel for B&W for CNN
#https://machinelearningmastery.com/a-gentle-introduction-to-channels-first-and-channels-last-image-formats-for-deep-learning/

print(X_train.shape,y_train.shape)
X_train=np.expand_dims(X_train,axis=3)
X_val=np.expand_dims(X_val,axis=3)
print(X_train.shape,X_val.shape)
# Out:
# (4000, 224, 224) (4000, 2)
# (4000, 224, 224, 1) (1000, 224, 224, 1)

# %% [markdown]
# ## The model
#
# []

# %%
tf.keras.backend.clear_session()

# %%
input_shape=(224,224,1)
inputs = tf.keras.layers.Input(shape=input_shape)
x=tf.keras.layers.Conv2D(64,(3,3),activation='relu')(inputs)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Conv2D(64,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Dropout(0.25)(x)
x=tf.keras.layers.Conv2D(128,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Conv2D(128,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Dropout(0.25)(x)

x=tf.keras.layers.Flatten()(x)
x=tf.keras.layers.Dense(256,activation='relu')(x)
x=tf.keras.layers.Dropout(0.5)(x)
x=tf.keras.layers.Dense(64,activation='relu')(x)
regression_layer_lat = tf.keras.layers.Dense(1, name='regression_lat')(x)  
regression_layer_long = tf.keras.layers.Dense(1, name='regression_long')(x)

model_output = [regression_layer_lat, regression_layer_long]
losses = ['mean_squared_error', 'mean_squared_error']
metrics = ['mean_squared_error', 'mean_squared_error']

model = tf.keras.models.Model(inputs, model_output)
model.compile(loss=losses,  optimizer='adam', metrics=metrics)

# %%
#model splits into lat long after convolutional layers

input_shape=(224,224,1)
inputs = tf.keras.layers.Input(shape=input_shape)
x=tf.keras.layers.Conv2D(64,(3,3),activation='relu')(inputs)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Conv2D(64,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Dropout(0.25)(x)
x=tf.keras.layers.Conv2D(128,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Conv2D(128,(3,3),activation='relu')(x)
x=tf.keras.layers.MaxPooling2D((2,2))(x)
x=tf.keras.layers.Dropout(0.25)(x)
x=tf.keras.layers.Flatten()(x)

xlat=tf.keras.layers.Dense(256,activation='relu')(x)
xlat=tf.keras.layers.Dropout(0.5)(xlat)
xlat=tf.keras.layers.Dense(64,activation='relu')(xlat)
regression_layer_lat = tf.keras.layers.Dense(1, name='regression_lat')(xlat)  

xlong=tf.keras.layers.Dense(256,activation='relu')(x)
xlong=tf.keras.layers.Dropout(0.5)(xlong)
xlong=tf.keras.layers.Dense(64,activation='relu')(xlong)
regression_layer_long = tf.keras.layers.Dense(1, name='regression_long')(xlong)

model_output = [regression_layer_lat, regression_layer_long]
losses = ['mean_squared_error', 'mean_squared_error']
metrics = ['mean_squared_error', 'mean_squared_error']

model = tf.keras.models.Model(inputs, model_output)
model.compile(loss=losses,  optimizer='adam', metrics=metrics)

# %%
print(model.summary())
#plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 222, 222, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 111, 111, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 109, 109, 64) 36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 54, 54, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 52, 52, 128)  73856       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 26, 26, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 128)  147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 12, 12, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          4718848     flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          4718848     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           16448       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           16448       dropout_3[0][0]
# __________________________________________________________________________________________________
# regression_lat (Dense)          (None, 1)            65          dense_1[0][0]
# __________________________________________________________________________________________________
# regression_long (Dense)         (None, 1)            65          dense_3[0][0]
# ==================================================================================================
# Total params: 9,729,730
# Trainable params: 9,729,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ### Fit the model

# %%
history = model.fit(x=X_train, 
                    y=[y_train[:,0],y_train[:,1]],
                    validation_data=[X_val,[y_val[:,0],y_val[:,1]]],
                    verbose=1, epochs=20, batch_size=128)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/20
# 4000/4000 [==============================] - 43s 11ms/sample - loss: 0.4258 - regression_lat_loss: 0.2164 - regression_long_loss: 0.2073 - regression_lat_mean_squared_error: 0.2166 - regression_long_mean_squared_error: 0.2092 - val_loss: 0.3639 - val_regression_lat_loss: 0.1818 - val_regression_long_loss: 0.1822 - val_regression_lat_mean_squared_error: 0.1816 - val_regression_long_mean_squared_error: 0.1823
# Epoch 2/20
# 4000/4000 [==============================] - 38s 10ms/sample - loss: 0.3536 - regression_lat_loss: 0.1732 - regression_long_loss: 0.1794 - regression_lat_mean_squared_error: 0.1743 - regression_long_mean_squared_error: 0.1793 - val_loss: 0.3993 - val_regression_lat_loss: 0.1923 - val_regression_long_loss: 0.2070 - val_regression_lat_mean_squared_error: 0.1923 - val_regression_long_mean_squared_error: 0.2070
# Epoch 3/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.3529 - regression_lat_loss: 0.1762 - regression_long_loss: 0.1773 - regression_lat_mean_squared_error: 0.1754 - regression_long_mean_squared_error: 0.1775 - val_loss: 0.3725 - val_regression_lat_loss: 0.1795 - val_regression_long_loss: 0.1932 - val_regression_lat_mean_squared_error: 0.1794 - val_regression_long_mean_squared_error: 0.1931
# Epoch 4/20
# 4000/4000 [==============================] - 41s 10ms/sample - loss: 0.3502 - regression_lat_loss: 0.1706 - regression_long_loss: 0.1775 - regression_lat_mean_squared_error: 0.1715 - regression_long_mean_squared_error: 0.1788 - val_loss: 0.3562 - val_regression_lat_loss: 0.1727 - val_regression_long_loss: 0.1836 - val_regression_lat_mean_squared_error: 0.1724 - val_regression_long_mean_squared_error: 0.1838
# Epoch 5/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.3485 - regression_lat_loss: 0.1712 - regression_long_loss: 0.1742 - regression_lat_mean_squared_error: 0.1720 - regression_long_mean_squared_error: 0.1765 - val_loss: 0.3570 - val_regression_lat_loss: 0.1761 - val_regression_long_loss: 0.1810 - val_regression_lat_mean_squared_error: 0.1759 - val_regression_long_mean_squared_error: 0.1811
# Epoch 6/20
# 4000/4000 [==============================] - 41s 10ms/sample - loss: 0.3403 - regression_lat_loss: 0.1661 - regression_long_loss: 0.1728 - regression_lat_mean_squared_error: 0.1673 - regression_long_mean_squared_error: 0.1730 - val_loss: 0.3700 - val_regression_lat_loss: 0.1784 - val_regression_long_loss: 0.1916 - val_regression_lat_mean_squared_error: 0.1782 - val_regression_long_mean_squared_error: 0.1917
# Epoch 7/20
# 4000/4000 [==============================] - 43s 11ms/sample - loss: 0.3401 - regression_lat_loss: 0.1667 - regression_long_loss: 0.1731 - regression_lat_mean_squared_error: 0.1669 - regression_long_mean_squared_error: 0.1732 - val_loss: 0.3603 - val_regression_lat_loss: 0.1735 - val_regression_long_loss: 0.1866 - val_regression_lat_mean_squared_error: 0.1734 - val_regression_long_mean_squared_error: 0.1869
# Epoch 8/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.3371 - regression_lat_loss: 0.1648 - regression_long_loss: 0.1712 - regression_lat_mean_squared_error: 0.1657 - regression_long_mean_squared_error: 0.1713 - val_loss: 0.3553 - val_regression_lat_loss: 0.1714 - val_regression_long_loss: 0.1837 - val_regression_lat_mean_squared_error: 0.1714 - val_regression_long_mean_squared_error: 0.1839
# Epoch 9/20
# 4000/4000 [==============================] - 43s 11ms/sample - loss: 0.3313 - regression_lat_loss: 0.1626 - regression_long_loss: 0.1690 - regression_lat_mean_squared_error: 0.1615 - regression_long_mean_squared_error: 0.1698 - val_loss: 0.3653 - val_regression_lat_loss: 0.1790 - val_regression_long_loss: 0.1860 - val_regression_lat_mean_squared_error: 0.1789 - val_regression_long_mean_squared_error: 0.1864
# Epoch 10/20
# 4000/4000 [==============================] - 43s 11ms/sample - loss: 0.3264 - regression_lat_loss: 0.1591 - regression_long_loss: 0.1644 - regression_lat_mean_squared_error: 0.1610 - regression_long_mean_squared_error: 0.1654 - val_loss: 0.3638 - val_regression_lat_loss: 0.1775 - val_regression_long_loss: 0.1860 - val_regression_lat_mean_squared_error: 0.1773 - val_regression_long_mean_squared_error: 0.1865
# Epoch 11/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.3189 - regression_lat_loss: 0.1551 - regression_long_loss: 0.1634 - regression_lat_mean_squared_error: 0.1555 - regression_long_mean_squared_error: 0.1634 - val_loss: 0.3742 - val_regression_lat_loss: 0.1829 - val_regression_long_loss: 0.1912 - val_regression_lat_mean_squared_error: 0.1828 - val_regression_long_mean_squared_error: 0.1914
# Epoch 12/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.3154 - regression_lat_loss: 0.1562 - regression_long_loss: 0.1612 - regression_lat_mean_squared_error: 0.1547 - regression_long_mean_squared_error: 0.1607 - val_loss: 0.3792 - val_regression_lat_loss: 0.1928 - val_regression_long_loss: 0.1865 - val_regression_lat_mean_squared_error: 0.1923 - val_regression_long_mean_squared_error: 0.1870
# Epoch 13/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.3082 - regression_lat_loss: 0.1511 - regression_long_loss: 0.1593 - regression_lat_mean_squared_error: 0.1502 - regression_long_mean_squared_error: 0.1580 - val_loss: 0.3716 - val_regression_lat_loss: 0.1795 - val_regression_long_loss: 0.1919 - val_regression_lat_mean_squared_error: 0.1794 - val_regression_long_mean_squared_error: 0.1923
# Epoch 14/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.2959 - regression_lat_loss: 0.1452 - regression_long_loss: 0.1504 - regression_lat_mean_squared_error: 0.1451 - regression_long_mean_squared_error: 0.1508 - val_loss: 0.3824 - val_regression_lat_loss: 0.1869 - val_regression_long_loss: 0.1953 - val_regression_lat_mean_squared_error: 0.1867 - val_regression_long_mean_squared_error: 0.1958
# Epoch 15/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.2848 - regression_lat_loss: 0.1369 - regression_long_loss: 0.1476 - regression_lat_mean_squared_error: 0.1372 - regression_long_mean_squared_error: 0.1477 - val_loss: 0.3807 - val_regression_lat_loss: 0.1837 - val_regression_long_loss: 0.1966 - val_regression_lat_mean_squared_error: 0.1836 - val_regression_long_mean_squared_error: 0.1971
# Epoch 16/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.2793 - regression_lat_loss: 0.1385 - regression_long_loss: 0.1426 - regression_lat_mean_squared_error: 0.1380 - regression_long_mean_squared_error: 0.1413 - val_loss: 0.4005 - val_regression_lat_loss: 0.1956 - val_regression_long_loss: 0.2047 - val_regression_lat_mean_squared_error: 0.1954 - val_regression_long_mean_squared_error: 0.2051
# Epoch 17/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.2649 - regression_lat_loss: 0.1293 - regression_long_loss: 0.1356 - regression_lat_mean_squared_error: 0.1288 - regression_long_mean_squared_error: 0.1361 - val_loss: 0.3922 - val_regression_lat_loss: 0.1879 - val_regression_long_loss: 0.2038 - val_regression_lat_mean_squared_error: 0.1880 - val_regression_long_mean_squared_error: 0.2043
# Epoch 18/20
# 4000/4000 [==============================] - 39s 10ms/sample - loss: 0.2506 - regression_lat_loss: 0.1202 - regression_long_loss: 0.1305 - regression_lat_mean_squared_error: 0.1213 - regression_long_mean_squared_error: 0.1292 - val_loss: 0.4125 - val_regression_lat_loss: 0.1990 - val_regression_long_loss: 0.2132 - val_regression_lat_mean_squared_error: 0.1990 - val_regression_long_mean_squared_error: 0.2135
# Epoch 19/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.2364 - regression_lat_loss: 0.1150 - regression_long_loss: 0.1223 - regression_lat_mean_squared_error: 0.1143 - regression_long_mean_squared_error: 0.1221 - val_loss: 0.4164 - val_regression_lat_loss: 0.1952 - val_regression_long_loss: 0.2210 - val_regression_lat_mean_squared_error: 0.1952 - val_regression_long_mean_squared_error: 0.2212
# Epoch 20/20
# 4000/4000 [==============================] - 40s 10ms/sample - loss: 0.2227 - regression_lat_loss: 0.1096 - regression_long_loss: 0.1154 - regression_lat_mean_squared_error: 0.1090 - regression_long_mean_squared_error: 0.1138 - val_loss: 0.4194 - val_regression_lat_loss: 0.1933 - val_regression_long_loss: 0.2261 - val_regression_lat_mean_squared_error: 0.1934 - val_regression_long_mean_squared_error: 0.2260

# %% [markdown]
# ### Evaluate model performance

# %%
history_df = pd.DataFrame(history.history)
ax = history_df.plot(y=['loss', 'val_loss'],
                xticks=np.linspace(0, len(history_df), 6))
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.set_title('Evolution of Mean Squared Error')
plt.show()

# %%
y_hat = model.predict(X_val)
#y_hat_lat=model.predict(X_val)[0]
#y_hat_long=model.predict(X_val)[1]
y_hat_lat=y_hat[0]
y_hat_long=y_hat[1]

y_hat_lat=scale_up(y_hat_lat,toplat,bottomlat)
y_hat_long=scale_up(y_hat_long,toplong,bottomlong)

y_val_lat=y_val[:,0]
y_val_long=y_val[:,1]

y_val_lat=scale_up(y_val_lat,toplat,bottomlat)
y_val_long=scale_up(y_val_long,toplong,bottomlong)

# %%
plt.scatter(y_val_lat, y_hat_lat)
plt.title('Predicted lat vs. True lat')
plt.xlabel('True lat')
plt.ylabel('Predicted lat')
plt.show()

# %%
plt.scatter(y_val_long, y_hat_long)
plt.title('Predicted long vs. True long')
plt.xlabel('True long')
plt.ylabel('Predicted long')
plt.show()

# %% [markdown]
# ### Feed Forward Dense

# %%
#just dense

input_shape=(224,224,1)
inputs = tf.keras.layers.Input(shape=input_shape)
x=tf.keras.layers.Flatten()(inputs)
x=tf.keras.layers.Dense(528,activation='relu')(x)
x=tf.keras.layers.Dense(528,activation='relu')(x)
x=tf.keras.layers.Dense(528,activation='relu')(x)

xlat=tf.keras.layers.Dense(256,activation='relu')(x)
xlat=tf.keras.layers.Dropout(0.25)(xlat)
xlat=tf.keras.layers.Dense(256,activation='relu')(xlat)
regression_layer_lat = tf.keras.layers.Dense(1, name='regression_lat')(xlat)  

xlong=tf.keras.layers.Dense(256,activation='relu')(x)
xlong=tf.keras.layers.Dropout(0.25)(xlong)
xlong=tf.keras.layers.Dense(256,activation='relu')(xlong)
regression_layer_long = tf.keras.layers.Dense(1, name='regression_long')(xlong)

model_output = [regression_layer_lat, regression_layer_long]
losses = ['mean_squared_error', 'mean_squared_error']
metrics = ['mean_squared_error', 'mean_squared_error']

model = tf.keras.models.Model(inputs, model_output)
model.compile(loss=losses,  optimizer='adam', metrics=metrics)
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 1) 0
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 50176)        0           input_3[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 528)          26493456    flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 528)          279312      dense_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 528)          279312      dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          135424      dense_13[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          135424      dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          65792       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 256)          65792       dropout_7[0][0]
# __________________________________________________________________________________________________
# regression_lat (Dense)          (None, 1)            257         dense_15[0][0]
# __________________________________________________________________________________________________
# regression_long (Dense)         (None, 1)            257         dense_17[0][0]
# ==================================================================================================
# Total params: 27,455,026
# Trainable params: 27,455,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = model.fit(x=X_train, 
                    y=[y_train[:,0],y_train[:,1]],
                    validation_data=[X_val,[y_val[:,0],y_val[:,1]]],
                    verbose=1, epochs=20, batch_size=128)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/20
# 4000/4000 [==============================] - 8s 2ms/sample - loss: 2.0387 - regression_lat_loss: 0.8447 - regression_long_loss: 1.1658 - regression_lat_mean_squared_error: 0.8550 - regression_long_mean_squared_error: 1.1837 - val_loss: 0.6580 - val_regression_lat_loss: 0.3201 - val_regression_long_loss: 0.3377 - val_regression_lat_mean_squared_error: 0.3201 - val_regression_long_mean_squared_error: 0.3379
# Epoch 2/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.6928 - regression_lat_loss: 0.3413 - regression_long_loss: 0.3514 - regression_lat_mean_squared_error: 0.3413 - regression_long_mean_squared_error: 0.3516 - val_loss: 0.6555 - val_regression_lat_loss: 0.3144 - val_regression_long_loss: 0.3413 - val_regression_lat_mean_squared_error: 0.3143 - val_regression_long_mean_squared_error: 0.3412
# Epoch 3/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.6259 - regression_lat_loss: 0.3081 - regression_long_loss: 0.3141 - regression_lat_mean_squared_error: 0.3084 - regression_long_mean_squared_error: 0.3176 - val_loss: 0.5195 - val_regression_lat_loss: 0.2663 - val_regression_long_loss: 0.2531 - val_regression_lat_mean_squared_error: 0.2660 - val_regression_long_mean_squared_error: 0.2536
# Epoch 4/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.4655 - regression_lat_loss: 0.2301 - regression_long_loss: 0.2327 - regression_lat_mean_squared_error: 0.2321 - regression_long_mean_squared_error: 0.2334 - val_loss: 0.3771 - val_regression_lat_loss: 0.1829 - val_regression_long_loss: 0.1943 - val_regression_lat_mean_squared_error: 0.1828 - val_regression_long_mean_squared_error: 0.1943
# Epoch 5/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3892 - regression_lat_loss: 0.1887 - regression_long_loss: 0.2007 - regression_lat_mean_squared_error: 0.1882 - regression_long_mean_squared_error: 0.2010 - val_loss: 0.3974 - val_regression_lat_loss: 0.1948 - val_regression_long_loss: 0.2024 - val_regression_lat_mean_squared_error: 0.1949 - val_regression_long_mean_squared_error: 0.2025
# Epoch 6/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3781 - regression_lat_loss: 0.1807 - regression_long_loss: 0.1954 - regression_lat_mean_squared_error: 0.1817 - regression_long_mean_squared_error: 0.1964 - val_loss: 0.4483 - val_regression_lat_loss: 0.2566 - val_regression_long_loss: 0.1918 - val_regression_lat_mean_squared_error: 0.2560 - val_regression_long_mean_squared_error: 0.1922
# Epoch 7/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3838 - regression_lat_loss: 0.1944 - regression_long_loss: 0.1900 - regression_lat_mean_squared_error: 0.1929 - regression_long_mean_squared_error: 0.1909 - val_loss: 0.3782 - val_regression_lat_loss: 0.1860 - val_regression_long_loss: 0.1922 - val_regression_lat_mean_squared_error: 0.1859 - val_regression_long_mean_squared_error: 0.1923
# Epoch 8/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3571 - regression_lat_loss: 0.1715 - regression_long_loss: 0.1834 - regression_lat_mean_squared_error: 0.1714 - regression_long_mean_squared_error: 0.1857 - val_loss: 0.3816 - val_regression_lat_loss: 0.1794 - val_regression_long_loss: 0.2024 - val_regression_lat_mean_squared_error: 0.1793 - val_regression_long_mean_squared_error: 0.2023
# Epoch 9/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3491 - regression_lat_loss: 0.1743 - regression_long_loss: 0.1752 - regression_lat_mean_squared_error: 0.1735 - regression_long_mean_squared_error: 0.1756 - val_loss: 0.3703 - val_regression_lat_loss: 0.1788 - val_regression_long_loss: 0.1916 - val_regression_lat_mean_squared_error: 0.1786 - val_regression_long_mean_squared_error: 0.1917
# Epoch 10/20
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3543 - regression_lat_loss: 0.1742 - regression_long_loss: 0.1792 - regression_lat_mean_squared_error: 0.1733 - regression_long_mean_squared_error: 0.1810 - val_loss: 0.3888 - val_regression_lat_loss: 0.1761 - val_regression_long_loss: 0.2130 - val_regression_lat_mean_squared_error: 0.1760 - val_regression_long_mean_squared_error: 0.2128
# Epoch 11/20
# 2688/4000 [===================>..........] - ETA: 2s - loss: 0.3602 - regression_lat_loss: 0.1749 - regression_long_loss: 0.1852 - regression_lat_mean_squared_error: 0.1749 - regression_long_mean_squared_error: 0.1852

# %% [markdown]
# ### Things to consider doing:
# - don't normalize the lat and long - just scale it DONE
# - convert back to lat and long DONE
# - set validation batch size to deal with OOM errors (possibly) DONE
# - loss weights?
# - what is resolution of png files coming in?  are they squares?
# - since set wide rectangle, need to make sure entirely at night time
# - change angle of view - look more tired horizon?

# %% [markdown]
# ### Old models

# %%
# Define Input layer(s)
inputShape = (224, 224)
inputs = tf.keras.layers.Input(shape=inputShape)

flatten = tf.keras.layers.Flatten()(inputs)

x=tf.keras.layers.Dense(512,activation='relu')(flatten)
x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dense(512,activation='relu')(x)
regression_layer_lat = tf.keras.layers.Dense(1, name='regression_lat')(x)  
regression_layer_long = tf.keras.layers.Dense(1, name='regression_long')(x)


# Build and compile model
model_input = inputs
model_output = [regression_layer_lat, regression_layer_long]
losses = ['mean_squared_error', 'mean_squared_error']
metrics = ['mean_squared_error', 'mean_squared_error']

model = tf.keras.models.Model(model_input, model_output)
model.compile(loss=losses,  optimizer='adam', metrics=metrics)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(224,224)),
    tf.keras.layers.Dense(512, activation='relu'),
    #tf.keras.layers.Dense(512, activation='relu'),
    #tf.keras.layers.Dense(512, activation='relu'),
    #tf.keras.layers.Dense(512, activation='relu'),
    #tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    #tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(2)
])
